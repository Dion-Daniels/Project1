# %% [markdown]
# ### Note
# * Instructions have been included for each segment. You do not have to follow them exactly, but they are included to help you think through the steps.

# %%
# Dependencies and Setup
import pandas as pd
from datetime import datetime 
import matplotlib.pyplot as plt
import scipy.stats as st
import numpy as np

# Read Ironore_price_market_index_test.csv File and store into Pandas data frame

perth_data = pd.read_csv('Outputs/perth_iron_housing.csv')
sydney_data = pd.read_csv('Outputs/sydney_iron_housing.csv')
complete_data = pd.read_csv('Outputs/complete_house_commodities.csv')
three_bed_data = pd.read_csv('Outputs/three_bed_housing.csv')
four_bed_data = pd.read_csv('Outputs/four_bed_housing.csv')
four_b_two_bath_data = pd.read_csv('Outputs/four_bed_two_bath_housing.csv')
#purchase_data

# %%
complete_data
# Out:
#         Unnamed: 0      ID     Date  Iron_Price  Silver_Price Gold_Price  \
# 0                0       1  2007-01       36.63         13.36     650.50
# 1                1       2  2007-01       36.63         13.36     650.50
# 2                2       3  2007-01       36.63         13.36     650.50
# 3                3       4  2007-01       36.63         13.36     650.50
# 4                4       5  2007-01       36.63         13.36     650.50
# ...            ...     ...      ...         ...           ...        ...
# 223708      223708  223709  2019-06      112.90         15.22   1,409.00
# 223709      223709  223710  2019-06      112.90         15.22   1,409.00
# 223710      223710  223711  2019-06      112.90         15.22   1,409.00
# 223711      223711  223712  2019-06      112.90         15.22   1,409.00
# 223712      223712  223713  2019-06      112.90         15.22   1,409.00
#
#         Copper_Price S&P_GSCI_Price         SUBURB   PRICE  BEDROOMS  \
# ...
